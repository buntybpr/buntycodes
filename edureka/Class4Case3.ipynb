# %%
import pandas as pd
import matplotlib.pyplot as pt
import numpy as np

# %%
dfhur = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/Hurricanes.csv')
dfhur.plot(kind='bar',x= 'Year', y = 'Hurricanes', figsize=[16,8])
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
dfctemp = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/CityTemps.csv')
dfctemp.plot(kind='hist',x='Moscow',y='San Francisco')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df_data_file = pd.read_csv("D:/gitrepo/buntycodes/edureka/Class4DataSets/data_file.txt")
df_data_file.to_csv("D:/gitrepo/buntycodes/edureka/Class4DataSets/data_file.csv")

# %%
X = [1,2,3,4]
Y = [20, 21, 20.5, 20.8]
pt.plot(X,Y)

# %%
pt.plot(X, Y)
pt.grid()

# %%
pt.setp(pt.gca().get_xticklabels(), rotation=90, horizontalalignment='right')  
pt.show()

# %%
pt.plot(X, Y)
pt.xlabel("x axis")
pt.ylabel("y axis")
pt.show()

# %%
y_error = [0.12, 0.13, 0.2, 0.1]
pt.figure(figsize=(4, 5),dpi=100)
pt.rcParams.update({'font.size': 14})
pt.plot(X, Y, y_error)
pt.xlabel("x axis")
pt.ylabel("y axis")
pt.show()

# %%
x = np.random.random(50)
y = np.random.random(50)

pt.scatter(x, y)
pt.show()

# %%
df = pd.DataFrame({'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73], 'preTestScore': [4, 24, 31, 2, 3],'postTestScore': [25, 94, 57, 62, 70]})

# %%
pt.scatter(df["preTestScore"], df["postTestScore"])
pt.xlabel("preTestScore")
pt.ylabel("postTestScore")
pt.title("preTestScore vs postTestScore")
pt.legend(["preTestScore", "postTestScore"])
pt.show()

# %%
df = pd.DataFrame({
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
})

x = df["preTestScore"]
y = df["postTestScore"]
colors = df["female"]

pt.scatter(x, y, c=colors, alpha=0.5)
pt.xlabel("preTestScore")
pt.ylabel("postTestScore")
pt.title("preTestScore vs postTestScore")
pt.legend(["preTestScore", "postTestScore"])
pt.show()
