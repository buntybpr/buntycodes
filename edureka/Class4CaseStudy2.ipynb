# %%
import pandas as pd
import numpy as np

# %%
df_math = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/MathScoreTerm1.csv')
df_physics = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/PhysicsScoreTerm1.csv')
df_dss = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/DSScoreTerm1.csv')

# %%
df_math.head()
df_physics.head()
df_dss.head()
# Out:
#              Name  Score  Age         Ethinicity        Subject Sex  ID
# 0  AI-KYUNG CHUNG   82.0   18     White American  Data Structue   M   1
# 1     ALAN HARVEY   79.0   19  European American  Data Structue   M   2
# 2    ALAN REYNAUD   39.0   19  European American  Data Structue   M   3
# 3  ALBERT CENDANA   76.0   18     White American  Data Structue   M   4
# 4  ALBERT HOLT JR   76.0   18     White American  Data Structue   F   5

# %%
#remove the name and ethnicity column
df_math.drop(columns=['Name','Ethinicity'],inplace=True)
df_physics.drop(columns=['Name','Ethinicity'],inplace=True)
df_dss.drop(columns=['Name','Ethinicity'],inplace=True)

# %%
df_math.head(100)
# Out:
#     Score  Age Subject Sex   ID
# 0    88.0   18   Maths   M    1
# 1    85.0   19   Maths   M    2
# 2    45.0   19   Maths   M    3
# 3    82.0   18   Maths   M    4
# 4    82.0   18   Maths   F    5
# ..    ...  ...     ...  ..  ...
# 95   75.0   18   Maths   M   96
# 96   88.0   19   Maths   M   97
# 97   95.0   18   Maths   M   98
# 98   65.0   21   Maths   M   99
# 99   65.0   19   Maths   F  100
#
# [100 rows x 5 columns]

# %%
df_math.fillna(0)
df_physics.fillna(0)
df_dss.fillna(0)
# Out:
#      Score  Age        Subject Sex   ID
# 0     82.0   18  Data Structue   M    1
# 1     79.0   19  Data Structue   M    2
# 2     39.0   19  Data Structue   M    3
# 3     76.0   18  Data Structue   M    4
# 4     76.0   18  Data Structue   F    5
# ..     ...  ...            ...  ..  ...
# 594   39.0   19  Data Structue   F  595
# 595   69.0   18  Data Structue   M  596
# 596   47.0   20  Data Structue   M  597
# 597   69.0   20  Data Structue   M  598
# 598    0.0   19  Data Structue   M  599
#
# [599 rows x 5 columns]

# %%
#merge files
df_all = df_math.join(df_physics,on = 'ID' ,how='left',lsuffix='_math',rsuffix='_physics').join(df_dss,on = 'ID_math' ,how='left',rsuffix='_dss')
df_all

# %%
df_all["Sex"] = [1 if sex == "M" else 2 for sex in df_all["Sex"]]

# %%
df_all
# Out:
#      Score_math  Age_math Subject_math Sex_math  ID_math  Score_physics  \
# 0          88.0        18        Maths        1        1           81.0
# 1          85.0        19        Maths        1        2           41.0
# 2          45.0        19        Maths        1        3           78.0
# 3          82.0        18        Maths        1        4           78.0
# 4          82.0        18        Maths        F        5           91.0
# ..          ...       ...          ...      ...      ...            ...
# 594        45.0        19        Maths        F      595           71.0
# 595        75.0        18        Maths        1      596           49.0
# 596        53.0        20        Maths        1      597           71.0
# 597        75.0        20        Maths        1      598           69.0
# 598        88.0        19        Maths        1      599            NaN
#
#      Age_physics Subject_physics Sex_physics  ID_physics  Score   Age  \
# ...

# %%
#convert ethinicity to numbers
df_math = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/MathScoreTerm1.csv')
df_physics = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/PhysicsScoreTerm1.csv')
df_dss = pd.read_csv('D:/gitrepo/buntycodes/edureka/Class4DataSets/DSScoreTerm1.csv')

# %%
enum_ethnicity = {'White American' : 1, 'European American':2, 'Hispanic':3,'African American':4}
df_math['Ethinicity']= df_math['Ethinicity'].map(enum_ethnicity)

# %%
df_math
# Out:
#                           Name  Score  Age  Ethinicity Subject Sex   ID
# 0               AI-KYUNG CHUNG   88.0   18           1   Maths   M    1
# 1                  ALAN HARVEY   85.0   19           2   Maths   M    2
# 2                 ALAN REYNAUD   45.0   19           2   Maths   M    3
# 3               ALBERT CENDANA   82.0   18           1   Maths   M    4
# 4               ALBERT HOLT JR   82.0   18           1   Maths   F    5
# ..                         ...    ...  ...         ...     ...  ..  ...
# 594                    WING NG   45.0   19           1   Maths   F  595
# 595                YIFANG QIAN   75.0   18           1   Maths   M  596
# 596           ZACHARY PUMPHREY   53.0   20           1   Maths   M  597
# 597  ZEBA IMAN NAZEERI-SIMMONS   75.0   20           3   Maths   M  598
# 598            ZHI JIAR ZHUANG   88.0   19           3   Maths   M  599
#
# [599 rows x 7 columns]

# %%
#Fill the missing score for a student to the average of the class
df_math['Score'].fillna(df_math['Score'].mean(),inplace=True)

# %%
df_math.head(60)
# Out:
#                          Name      Score  Age  Ethinicity Subject Sex  ID
# 0              AI-KYUNG CHUNG  88.000000   18           1   Maths   M   1
# 1                 ALAN HARVEY  85.000000   19           2   Maths   M   2
# 2                ALAN REYNAUD  45.000000   19           2   Maths   M   3
# 3              ALBERT CENDANA  82.000000   18           1   Maths   M   4
# 4              ALBERT HOLT JR  82.000000   18           1   Maths   F   5
# 5              ALBERT PARDINI  95.000000   20           1   Maths   M   6
# 6                   ALBERT YU  95.000000   18           1   Maths   M   7
# 7             ALBERTO PEDRUCO  65.000000   19           1   Maths   M   8
# 8                  ALEC BALMY  88.000000   18           3   Maths   M   9
# 9           ALEETA VAN RUNKLE  88.000000   19           3   Maths   F  10
# 10                   ALEX TSE  53.000000   20           1   Maths   M  11
# 11             ALEXANDER CHEN  53.000000   20           1   Maths   M  12
# ...
